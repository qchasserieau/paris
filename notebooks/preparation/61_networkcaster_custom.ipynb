# %%
import pandas as pd
import sys
sys.path.insert(0, r'../../../quetzal')

from quetzal.io import  gtfs_importer
from quetzal.model import stepmodel, model
# %matplotlib inline

# %%
training_folder = '../../'

# %%
sm = stepmodel.read_zip(training_folder + 'model/preparation/road.zip')
# Out:
# read_hdf: : 100%|██████████████████████████████████████████████████████████████████████| 22/22 [00:00<00:00, 33.28it/s]

# %%
road = stepmodel.read_zip(training_folder + 'model/preparation/sandbox.zip')
sm.links = road.links
sm.nodes = road.nodes
# Out:
# read_hdf: : 100%|██████████████████████████████████████████████████████████████████████| 22/22 [00:00<00:00, 82.09it/s]

# %%
sm.plot('links', ax=sm.plot('nodes', color='green'))

# %% [markdown]
# # Networkcaster
# à faire sur un réseau propre, avant l'agrégation

# %%
sm.integrity_test_all(errors='raise', verbose=False)
# Out:
# 10006it [00:00, 10510.99it/s]
# 10006it [00:03, 2542.20it/s]

# %%
sm.preparation_cast_network(
    nearest_method='nodes',
    n_neighbors_centroid=10, 
    n_neighbors=5
)
# Out:
# nearest_link: 100%|███████████████████████████████████████████████████████████████| 350/350 [00:00<00:00, 87204.85it/s]
# 3100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:02<00:00,  1.84it/s]
# road_paths : 31it [00:00, 184.49it/s]

# %%
sm.to_zip(
    training_folder + 'model/preparation/sandbox_networkcasted.zip'
)
# Out:
# to_hdf(new file): 100%|████████████████████████████████████████████████████████████████| 33/33 [00:02<00:00, 14.90it/s]
# could not save attribute: missing_nodes
# could not save attribute: missing_road_nodes
# could not save attribute: networkcaster

# %%
sm.analysis_lines()

# %%
sm.plot('links', ax=sm.plot('nodes', color='green'))
