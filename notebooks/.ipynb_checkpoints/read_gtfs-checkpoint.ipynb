# %%
import sys
sys.path.insert(0, r'../libraries/quetzal')

# %%
from quetzal.io.import_gtfs import SimpleGtfsImporter

# %%
gtfs_path = r'../data/RATP_GTFS_FULL/'

# %%
importer = SimpleGtfsImporter(gtfs_path)

# %%
importer.read()

# %%
self = importer

# %%
# Out:
#         route_id  service_id           trip_id trip_headsign trip_short_name  \
# 0        1025209     2689845   126898451022105           NaN               1
# 1        1025209     2689845   226898451022105           NaN               2
# 2        1025209     2689845   326898451022105           NaN               3
# 3        1025209     2689845   426898451022105           NaN               4
# 4        1025209     2689845   526898451022105           NaN               5
# 5        1025209     2689845   626898451022105           NaN               6
# 6        1025209     2689845   726898451022105           NaN               7
# 7        1025209     2712234   127122341022105           NaN               1
# 8        1025209     2712234   227122341022105           NaN               2
# 9        1025209     2712234   327122341022105           NaN               3
# 10       1025209     2712234   427122341022105           NaN               4
# ...

# %%
stops['geometry'] = stops.apply(point_geometry, axis=1)
links['geometry'] = linestring_geometry(
    links, 
    stops.set_index('stop_id')['geometry'].to_dict(), 
    'origin', 
    'destination'
)

# %%
links['time'] = links['arrival_time'] - links['departure_time']

# %%
routes
# Out:
#       route_id  agency_id       route_short_name  \
# 0      1025209        100                    292
# 1      1025210        100                    292
# 2      1025256        100                    192
# 3      1030436        100                    TIM
# 4      1040914        100                     V5
# 5      1067111        100                    303
# 6      1067198        100                    303
# 7      1086437        100                    355
# 8      1086484        100                    355
# 9      1086485        100                    355
# 10     1124785        100                    114
# 11     1124786        100                    262
# 12     1176285        100                    162
# 13     1176286        100                    162
# 14     1185393        100                     47
# 15     1197616        100                     11
# 16     1197617        100                     11
# 17     1197620        100                     13
# ...

# %%
links.rename(
    columns={
        'origin': 'a',
        'destination': 'b',
    },
    inplace=True

)
# Out:
#        index   origin            trip_id  sequence  departure_time  \
# 0          0     2090  10003887950313949         1          1200.0
# 1          1     2552  10003887950313951         1          1200.0
# 2          2    22789  10023352211618217         1         63360.0
# 3          3    22791  10023352211618217         2         63720.0
# 4          4    22794  10023352211618218         1         63720.0
# 5          5    22792  10023352211618218         2         63780.0
# 6          6  5121003  10026356811764084         1         63420.0
# 7          7  5121004  10026356811764084         2         63960.0
# 8          8  5121005  10026356811764084         3         64020.0
# 9          9  5121006  10026356811764084         4         64080.0
# 10        10  5121007  10026356811764084         5         64140.0
# 11        11  5121008  10026356811764084         6         64140.0
# 12        12  5121012  10026356881208004         1         64380.0
# ...
