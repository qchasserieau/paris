# %%
import sys
sys.path.insert(0, r'../../../quetzal')

from quetzal.io import  gtfs_importer
from quetzal.model import stepmodel

# %%
training_folder = '../../'

# %%
sm = stepmodel.read_zip(training_folder + r'model/preparation/walk_model.zip')
# Out:
# read_hdf: : 100%|██████████████████████████████████████████████████████████████████████| 22/22 [00:01<00:00, 17.81it/s]

# %% [markdown]
# # required fields !

# %%
sm.links['headway'] = 300
sm.links['length'] = sm.links['road_length']

# %%
sm.links['route_type'] = sm.links['route_type'].apply(
    lambda t: {
        0:'tram',
        1:'subway',
        2:'rail',
        3:'bus',
        4:'ferry',
        5:'cable_car',
        6:'gondola',
        7:'funicular'
    }[t]
)

# %% [markdown]
# # rail

# %%
rail = sm.copy()
rail.links = rail.links.loc[rail.links['route_type'].isin(['tram', 'subway', 'rail'])]

# %%
rail.step_pt_pathfinder(
    broken_routes=True,
    broken_modes=False
)
# Out:
# zone_100 100%|███████████████████████████████████████████████████████████████████████| 110/110 [00:01<00:00, 86.68it/s]
# breaking route: 939888 100%|███████████████████████████████████████████████████████████| 51/51 [00:29<00:00,  1.98it/s]
# path_analysis: 100%|██████████████████████████████████████████████████████████| 12882/12882 [00:00<00:00, 35484.28it/s]

# %%
rail.pt_los.set_index(['origin', 'destination'])['pathfinder_session'].value_counts()
# Out:
# best_path       12100
# route_braker      782
# Name: pathfinder_session, dtype: int64

# %%
sm.links.drop(['index'],axis=1,inplace=True,errors='ignore' )

# %%
sm.step_pt_pathfinder(
    broken_routes=False,
    broken_modes=True
)
# Out:
# zone_100 100%|███████████████████████████████████████████████████████████████████████| 110/110 [00:06<00:00, 17.77it/s]
# breaking modes: set() 100%|████████████████████████████████████████████████████████████| 16/16 [00:52<00:00,  5.38s/it]
# path_analysis: 100%|██████████████████████████████████████████████████████████| 54362/54362 [00:02<00:00, 21956.89it/s]

# %%
pathfound = sm.copy()

# %%
import pandas as pd
pathfound.pt_los = pd.concat(
    [sm.pt_los, rail.pt_los]
).drop_duplicates(subset=['path'])

# %%
pathfound.pt_los.set_index(['origin', 'destination'])['pathfinder_session'].value_counts()
# Out:
# mode_braker     42262
# best_path       12100
# route_braker      779
# Name: pathfinder_session, dtype: int64

# %% [markdown]
# # display

# %%
projected = pathfound.change_epsg(4326, 'degree')
# Out:
# Reprojecting model from epsg 2154 to epsg 4326: 100%|██████████████████████████████████| 31/31 [00:04<00:00,  7.10it/s]

# %%
from quetzal.io import display
from imp import reload
reload(display)
# Out:
# <module 'quetzal.io.display' from '../../../quetzal\\quetzal\\io\\display.py'>

# %%
from imp import reload
reload(display)
display.all_pt_paths(projected, 'zone_44',  'zone_73', color_column='route_color', group_name='route_short_name')
# Out:
# 9 paths
# 100%|████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:01<00:00,  4.61it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
pathfound.to_zip(training_folder + 'model/transport/pt_pathfinder.zip')
# Out:
# to_hdf(new file): 100%|████████████████████████████████████████████████████████████████| 31/31 [00:05<00:00,  5.68it/s]
