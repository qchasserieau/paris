# %%
import sys
sys.path.insert(0, r'../../libraries/quetzal')
sys.path.insert(0, r'../../libraries/syspy')

from quetzal.io import  gtfs_importer
from quetzal.model import stepmodel

# %%
training_folder = '../../'

# %%
sm = stepmodel.read_hdf(training_folder + r'model/preparation/walk_model.hdf')
# Out:
# read_hdf: : 100%|██████████████████████████████████████████████████████████████████████| 22/22 [00:00<00:00, 24.14it/s]

# %% [markdown]
# # miscellaneous

# %%
rainbow_shades = ["#D22328", "#559BB4", "#91A564", "#DC9100", "#8C4B7D", "#A08C69",
                  "#647D6E", "#5A7382", "#64411E", "#A00037", "#643C5A"]

sm.analysis_lines(line_columns='all')
sm.lines['route_color'] = list(rainbow_shades[:5]*10000)[: len(sm.lines)]
d = sm.lines.set_index('trip_id')['route_color'].to_dict()
sm.links['route_color'] = sm.links['trip_id'].apply(
    lambda x: d[x] if x in d.keys() else "#D22328"
)

# %% [markdown]
# # required fields !

# %%
sm.links['headway'] = 300
sm.links['length'] = sm.links['road_length']

# %% [markdown]
# # rail

# %%
rail = sm.copy()
rail.links = rail.links.loc[rail.links['route_type'].isin([0, 1, 2])]

# %%
rail.step_pt_pathfinder(
    broken_routes=True,
    broken_modes=False
)
# Out:
# zone_69 100%|████████████████████████████████████████████████████████████████████████| 110/110 [00:01<00:00, 72.27it/s]
# breaking route: 939888 100%|███████████████████████████████████████████████████████████| 51/51 [00:31<00:00,  1.96it/s]
# path_analysis: 100%|██████████████████████████████████████████████████████████| 12949/12949 [00:00<00:00, 23652.94it/s]

# %%
rail.pt_los.set_index(['origin', 'destination'])['pathfinder_session'].value_counts()
# Out:
# best_path       12100
# route_braker      849
# Name: pathfinder_session, dtype: int64

# %%
sm.links.drop(['index'],axis=1,inplace=True )

# %%
sm.step_pt_pathfinder(
    broken_routes=False,
    broken_modes=True
)
# Out:
# zone_69 100%|████████████████████████████████████████████████████████████████████████| 110/110 [00:05<00:00, 20.48it/s]
# breaking modes: set() 100%|████████████████████████████████████████████████████████████| 16/16 [00:49<00:00,  3.85s/it]
# path_analysis: 100%|██████████████████████████████████████████████████████████| 55728/55728 [00:02<00:00, 26593.13it/s]

# %%
sm.pt_los.loc[11728].iloc[1]
# Out:
# broken_modes                                               {0, 1, 2, 3}
# destination                                                     zone_32
# gtime                                                            5507.4
# origin                                                          zone_10
# path                  (zone_10, 807, 365, zone_12, 691, 521, 911, 17...
# pathfinder_session                                          mode_braker
# reversed                                                          False
# alighting_links                                                      []
# alightings                                                           []
# boarding_links                                                       []
# boardings                                                            []
# footpaths             [(807, 365), (691, 521), (521, 911), (911, 173...
# link_path                                                            []
# node_path             [807, 365, 691, 521, 911, 173, 423, 489, 40, 6...
# ntlegs                [(zone_10, 807), (365, zone_12), (zone_12, 691...
# transfers                                                            []
# all_walk                                                           True
# time_link_path                                                        0
# length_link_path                                                      0
# Name: 11728, dtype: object

# %%
pathfound = sm.copy()

# %%
import pandas as pd
pathfound.pt_los = pd.concat(
    [sm.pt_los, rail.pt_los]
).drop_duplicates(subset=['path'])

# %% [markdown]
# # display

# %%
projected = pathfound.change_epsg(4326, 'degree')
# Out:
# Reprojecting model from epsg 2154 to epsg 4326: 100%|██████████████████████████████████| 32/32 [00:04<00:00,  7.87it/s]

# %%
from quetzal.io import display
from imp import reload
reload(display)
# Out:
# <module 'quetzal.io.display' from '../../libraries/quetzal\\quetzal\\io\\display.py'>

# %%
from imp import reload
reload(display)
display.all_pt_paths(projected, 'zone_44',  'zone_73', color_column='route_color', group_name='route_short_name')
# Out:
# 11 paths
# 100%|██████████████████████████████████████████████████████████████████████████████████| 11/11 [00:02<00:00,  4.63it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
pathfound.to_hdf(training_folder + 'model/pathfinder.hdf')
# Out:
# to_hdf(overwriting): 100%|█████████████████████████████████████████████████████████████| 31/31 [00:05<00:00,  6.88it/s]
